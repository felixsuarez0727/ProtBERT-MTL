# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/... # Replace with your actual path
# !pip install -q --upgrade transformers scikit-learn pandas matplotlib seaborn scipy

# %%
import os
import json
import joblib
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from transformers import BertTokenizer
from datetime import datetime
from data.dataset import MultiTaskPeptideDataset
from model.model import BertMultiTaskModel, FocalLoss, HuberLoss
from training.trainer import train_improved, evaluate_improved, detailed_analysis
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def main():
    print("Starting multi-task BERT model training")
    print("="*60)

    # Set seeds for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)
        torch.cuda.manual_seed_all(42)

    # Load data
    print("Loading and preprocessing data...")
    df = pd.read_csv("./data/data_cpp_rfu_merge.csv")
    df = df.rename(columns={'peptide': 'sequence', 'y_df1': 'cpp_label', 'y_df2': 'rfu_label'})

    # Clean data
    df = df.dropna(subset=['sequence'])
    df['sequence'] = df['sequence'].astype(str)

    # Analyze CPP class distribution
    cpp_counts = df['cpp_label'].value_counts()
    print(f"Original CPP distribution: {cpp_counts}")

    # Handle class imbalance if needed
    if len(cpp_counts) > 1:
        minority_class_ratio = cpp_counts.min() / cpp_counts.max()
        print(f"Imbalance ratio: {minority_class_ratio:.3f}")

        if minority_class_ratio < 0.3:
            print("Applying class balancing...")
            from sklearn.utils import resample

            df_majority = df[df['cpp_label'] == cpp_counts.idxmax()]
            df_minority = df[df['cpp_label'] == cpp_counts.idxmin()]

            df_minority_upsampled = resample(df_minority,
                                           replace=True,
                                           n_samples=len(df_majority)//2,
                                           random_state=42)

            df = pd.concat([df_majority, df_minority_upsampled])
            print(f"New distribution: {df['cpp_label'].value_counts()}")

    # Normalize RFU
    print("Normalizing RFU data...")
    scaler = StandardScaler()
    non_null_rfu = df['rfu_label'].dropna().values.reshape(-1, 1)
    if non_null_rfu.size > 0:
        scaler.fit(non_null_rfu)
        df.loc[df['rfu_label'].notna(), 'rfu_label'] = scaler.transform(non_null_rfu).flatten()
        joblib.dump(scaler, "./saved_model/scaler.pkl")

    # Stratified split
    print("Splitting data with stratification...")
    stratify_var = df['cpp_label'].fillna(-999).astype(int)

    train_df, test_df = train_test_split(df, test_size=0.15, random_state=42,
                                        stratify=stratify_var)
    train_stratify = train_df['cpp_label'].fillna(-999).astype(int)
    train_df, val_df = train_test_split(train_df, test_size=0.15, random_state=42,
                                       stratify=train_stratify)

    print(f"Train: {len(train_df)} | Val: {len(val_df)} | Test: {len(test_df)}")

    # Configure datasets and loaders
    tokenizer = BertTokenizer.from_pretrained("Rostlab/prot_bert", do_lower_case=False)

    train_dataset = MultiTaskPeptideDataset(
        train_df['sequence'].tolist(), train_df['rfu_label'].tolist(),
        train_df['cpp_label'].tolist(), tokenizer, max_length=256
    )
    val_dataset = MultiTaskPeptideDataset(
        val_df['sequence'].tolist(), val_df['rfu_label'].tolist(),
        val_df['cpp_label'].tolist(), tokenizer, max_length=256
    )
    test_dataset = MultiTaskPeptideDataset(
        test_df['sequence'].tolist(), test_df['rfu_label'].tolist(),
        test_df['cpp_label'].tolist(), tokenizer, max_length=256
    )

    # DataLoaders
    batch_size = 8 if torch.cuda.is_available() else 4
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                             num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=2,
                           pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2,
                            pin_memory=True)

    # Model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BertMultiTaskModel(dropout=0.3, pooling_strategy='mean').to(device)

    # Optimizer
    bert_params = []
    head_params = []

    for name, param in model.named_parameters():
        if 'bert' in name:
            bert_params.append(param)
        else:
            head_params.append(param)

    optimizer = AdamW([
        {'params': bert_params, 'lr': 1e-5, 'initial_lr': 1e-5},
        {'params': head_params, 'lr': 5e-5, 'initial_lr': 5e-5}
    ], weight_decay=0.01, eps=1e-8)

    # Scheduler
    scheduler = ReduceLROnPlateau(
        optimizer, mode='min', factor=0.7, patience=6, verbose=True, min_lr=1e-8
    )

    # Loss functions
    loss_fn_rfu = HuberLoss(delta=0.5, reduction='mean')
    loss_fn_cpp = FocalLoss(alpha=1, gamma=2, reduction='mean')

    print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
    print(f"Trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

    # Training
    print("Starting training...")
    EPOCHS = 40
    alpha = 1.0  # RFU weight
    beta = 0.8   # CPP weight

    train_loss, best_rmse = train_improved(
        model=model, train_loader=train_loader, val_loader=val_loader,
        optimizer=optimizer, scheduler=scheduler, loss_fn_rfu=loss_fn_rfu,
        loss_fn_cpp=loss_fn_cpp, device=device, epochs=EPOCHS, patience=12,
        alpha=alpha, beta=beta, warmup_epochs=3
    )

    # Final evaluation
    print("Final evaluation on test set...")
    rmse, mae, r2, accuracy, f1 = evaluate_improved(
        model, test_loader, device, loss_fn_rfu, loss_fn_cpp, save_plots=True
    )

    print("\n" + "="*60)
    print("FINAL RESULTS:")
    print("="*60)
    print(f" RMSE (RFU): {rmse:.4f}")
    print(f" MAE (RFU): {mae:.4f}")
    print(f" R² (RFU): {r2:.4f}")
    print(f" Accuracy (CPP): {accuracy:.4f}")
    print(f" F1-Score (CPP): {f1:.4f}")
    print("="*60)

    # Save final metrics
    final_metrics = {
        'rmse': rmse,
        'mae': mae,
        'r2': r2,
        'accuracy': accuracy,
        'f1_score': f1,
        'train_loss': train_loss,
        'total_params': sum(p.numel() for p in model.parameters()),
        'trainable_params': sum(p.numel() for p in model.parameters() if p.requires_grad),
        'timestamp': datetime.now().isoformat()
    }

    with open('./saved_model/final_metrics.json', 'w') as f:
        json.dump(final_metrics, f, indent=2)

    print("Final metrics saved at ./saved_model/final_metrics.json")

    # Detailed analysis
    print("\nPerforming detailed analysis...")
    detailed_analysis(model, test_loader, device, scaler)

    # Save model configuration
    model_config = {
        'model_class': 'BertMultiTaskModel',
        'base_model': 'Rostlab/prot_bert',
        'dropout': 0.3,
        'pooling_strategy': 'mean',
        'max_length': 256,
        'batch_size': batch_size,
        'epochs_trained': EPOCHS,
        'optimizer': 'AdamW',
        'scheduler': 'ReduceLROnPlateau',
        'loss_functions': {
            'rfu': 'HuberLoss',
            'cpp': 'FocalLoss'
        },
        'task_weights': {
            'alpha': alpha,
            'beta': beta
        }
    }

    with open('./saved_model/model_config.json', 'w') as f:
        json.dump(model_config, f, indent=2)

    print("Model configuration saved at ./saved_model/model_config.json")

if __name__ == "__main__":
    main()
# Out:
# Starting multi-task BERT model training
# ============================================================
# Loading and preprocessing data...
# Original CPP distribution: cpp_label
# 0.0    184
# 1.0    184
# Name: count, dtype: int64
# Imbalance ratio: 1.000
# Normalizing RFU data...
# Splitting data with stratification...
# Train: 500 | Val: 89 | Test: 104
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# :26: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Total parameters: 421,313,155
# Trainable parameters: 52,816,515
# Starting training...
# 🚀 Iniciando entrenamiento mejorado por 40 épocas...
# 📦 Modelo: BertMultiTaskModel
# 🎯 Paciencia: 12
# 📱 Dispositivo: cuda
# ⚖️  Alpha (RFU): 1.00, Beta (CPP): 0.80
# 🔥 Warmup epochs: 3
# Época 1/40:   0%|          | 0/63 [00:00<?, ?it/s]FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:   2%|▏         | 1/63 [00:02<02:38,  2.55s/it, loss=0.7012, rfu=0.2829, cpp=0.4872, grad=nan]/training/trainer.py:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:   3%|▎         | 2/63 [00:03<01:22,  1.34s/it, loss=0.8351, rfu=0.6151, cpp=0.2393, grad=41.133]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:   8%|▊         | 5/63 [00:03<00:26,  2.22it/s, loss=0.7723, rfu=0.3136, cpp=0.5376, grad=54.022]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  16%|█▌        | 10/63 [00:04<00:12,  4.24it/s, loss=0.5911, rfu=0.2624, cpp=0.3751, grad=43.620]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  30%|███       | 19/63 [00:06<00:08,  5.36it/s, loss=0.4594, rfu=0.3723, cpp=0.0731, grad=25.010]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  33%|███▎      | 21/63 [00:06<00:07,  5.78it/s, loss=1.2288, rfu=0.6758, cpp=0.6556, grad=58.117]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  43%|████▎     | 27/63 [00:07<00:05,  6.07it/s, loss=0.1912, rfu=0.0987, cpp=0.0799, grad=40.971]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  60%|██████    | 38/63 [00:09<00:04,  6.19it/s, loss=1.5412, rfu=0.8666, cpp=0.8074, grad=52.716]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  63%|██████▎   | 40/63 [00:09<00:03,  6.01it/s, loss=0.7342, rfu=0.4249, cpp=0.3510, grad=52.930]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  71%|███████▏  | 45/63 [00:10<00:03,  5.96it/s, loss=0.5411, rfu=0.2755, cpp=0.2963, grad=40.943]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  84%|████████▍ | 53/63 [00:12<00:02,  3.79it/s, loss=0.5723, rfu=0.5248, cpp=0.0236, grad=21.778]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  90%|█████████ | 57/63 [00:13<00:01,  4.61it/s, loss=1.4018, rfu=0.4802, cpp=1.1163, grad=60.540]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 1/40:  94%|█████████▎| 59/63 [00:13<00:00,  5.05it/s, loss=0.4335, rfu=0.3708, cpp=0.0426, grad=25.326]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.599 ± 0.080
# 📊 Época   1 | Loss: 0.8229 | RFU_L: 0.4299 | CPP_L: 0.4555 | Val RMSE: 1.0765 | Val R²: 0.0208 | Val Acc: 0.6596 | Val F1: 0.6530 | Grad: nan
# Época 2/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:   2%|▏         | 1/63 [00:00<00:19,  3.16it/s, loss=0.6732, rfu=0.1973, cpp=0.5592, grad=46.633]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:  11%|█         | 7/63 [00:01<00:09,  5.96it/s, loss=1.2658, rfu=0.7649, cpp=0.5904, grad=44.337]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:  27%|██▋       | 17/63 [00:02<00:07,  6.09it/s, loss=0.8423, rfu=0.2856, cpp=0.6602, grad=40.218]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:  29%|██▊       | 18/63 [00:03<00:07,  6.08it/s, loss=1.1982, rfu=0.6736, cpp=0.6200, grad=50.113]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:  38%|███▊      | 24/63 [00:04<00:06,  5.99it/s, loss=0.5872, rfu=0.3941, cpp=0.2057, grad=35.323]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:  46%|████▌     | 29/63 [00:04<00:05,  5.82it/s, loss=0.7102, rfu=0.3430, cpp=0.4233, grad=36.693]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 2/40:
:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  48%|████▊     | 30/63 [00:05<00:05,  5.88it/s, loss=0.8967, rfu=0.2859, cpp=0.5394, grad=78.702]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  56%|█████▌    | 35/63 [00:06<00:04,  5.83it/s, loss=0.4983, rfu=0.2445, cpp=0.1797, grad=36.053]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  71%|███████▏  | 45/63 [00:07<00:03,  5.84it/s, loss=0.8023, rfu=0.3390, cpp=0.3756, grad=45.984]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  75%|███████▍  | 47/63 [00:08<00:02,  5.85it/s, loss=0.3500, rfu=0.2307, cpp=0.0438, grad=24.396]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  90%|█████████ | 57/63 [00:10<00:01,  5.77it/s, loss=1.1217, rfu=0.4151, cpp=0.6104, grad=61.083]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 11/40:  98%|█████████▊| 62/63 [00:10<00:00,  5.75it/s, loss=0.6324, rfu=0.1518, cpp=0.4340, grad=48.925]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.678 ± 0.119
# 📊 Época  11 | Loss: 0.6556 | RFU_L: 0.3015 | CPP_L: 0.2708 | Val RMSE: 0.8214 | Val R²: 0.4299 | Val Acc: 0.5319 | Val F1: 0.5306 | Grad: 43.714
# Época 12/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:   2%|▏         | 1/63 [00:00<00:21,  2.89it/s, loss=0.4696, rfu=0.3304, cpp=0.0387, grad=27.904]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:   5%|▍         | 3/63 [00:00<00:12,  4.75it/s, loss=0.7075, rfu=0.2027, cpp=0.4073, grad=49.669]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  13%|█▎        | 8/63 [00:01<00:09,  5.63it/s, loss=0.7338, rfu=0.3187, cpp=0.3001, grad=44.403]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  29%|██▊       | 18/63 [00:03<00:07,  5.82it/s, loss=0.6692, rfu=0.4579, cpp=0.0813, grad=36.708]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  32%|███▏      | 20/63 [00:03<00:07,  5.79it/s, loss=0.6156, rfu=0.3837, cpp=0.1152, grad=30.063]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  41%|████▏     | 26/63 [00:04<00:06,  5.79it/s, loss=0.3424, rfu=0.2002, cpp=0.0672, grad=26.156]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  56%|█████▌    | 35/63 [00:06<00:04,  5.82it/s, loss=0.7262, rfu=0.5020, cpp=0.0847, grad=32.115]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  59%|█████▊    | 37/63 [00:06<00:04,  5.87it/s, loss=0.9247, rfu=0.6316, cpp=0.1238, grad=37.606]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  68%|██████▊   | 43/63 [00:07<00:03,  5.71it/s, loss=2.2594, rfu=0.5018, cpp=1.5248, grad=80.341]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  83%|████████▎ | 52/63 [00:09<00:02,  5.39it/s, loss=0.7074, rfu=0.3620, cpp=0.2261, grad=49.957]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  86%|████████▌ | 54/63 [00:09<00:01,  5.49it/s, loss=0.9149, rfu=0.2505, cpp=0.5478, grad=83.522]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 12/40:  94%|█████████▎| 59/63 [00:10<00:00,  5.49it/s, loss=0.5356, rfu=0.3216, cpp=0.1106, grad=38.267]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.643 ± 0.088
# 📊 Época  12 | Loss: 0.7622 | RFU_L: 0.3145 | CPP_L: 0.3316 | Val RMSE: 0.7751 | Val R²: 0.4924 | Val Acc: 0.6170 | Val F1: 0.6167 | Grad: 46.175
# Mejor modelo guardado (RMSE: 0.7751, Acc: 0.6170)
# Época 13/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 13/40:   3%|▎         | 2/63 [00:00<00:16,  3.80it/s, loss=0.4971, rfu=0.2365, cpp=0.1713, grad=40.612]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 13/40
:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 14/40:  98%|█████████▊| 62/63 [00:12<00:00,  5.52it/s, loss=0.7091, rfu=0.4203, cpp=0.1034, grad=29.950]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.682 ± 0.105
# 📊 Época  14 | Loss: 0.7900 | RFU_L: 0.2838 | CPP_L: 0.3276 | Val RMSE: 0.8809 | Val R²: 0.3443 | Val Acc: 0.5532 | Val F1: 0.5415 | Grad: 48.687
# Época 15/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ...
#   with autocast():
# Época 29/40:  84%|████████▍ | 53/63 [00:09<00:01,  5.63it/s, loss=0.8784, rfu=0.2777, cpp=0.1472, grad=59.830]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 29/40:  94%|█████████▎| 59/63 [00:10<00:00,  5.75it/s, loss=0.9076, rfu=0.3010, cpp=0.1385, grad=48.380]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.703 ± 0.122
# 📊 Época  29 | Loss: 0.9977 | RFU_L: 0.2553 | CPP_L: 0.2292 | Val RMSE: 0.7876 | Val R²: 0.4759 | Val Acc: 0.5745 | Val F1: 0.5662 | Grad: 58.129
# Época 30/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  11%|█         | 7/63 [00:01<00:10,  5.48it/s, loss=1.0702, rfu=0.3559, cpp=0.1649, grad=46.693]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  16%|█▌        | 10/63 [00:01<00:09,  5.52it/s, loss=0.9664, rfu=0.3068, cpp=0.1622, grad=54.963]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  22%|██▏       | 14/63 [00:02<00:09,  5.26it/s, loss=1.3296, rfu=0.1868, cpp=0.4637, grad=69.809]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  32%|███▏      | 20/63 [00:03<00:08,  5.36it/s, loss=2.2062, rfu=0.6327, cpp=0.4561, grad=87.592]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  46%|████▌     | 29/63 [00:05<00:06,  5.45it/s, loss=1.5420, rfu=0.2767, cpp=0.4800, grad=73.668]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  49%|████▉     | 31/63 [00:05<00:05,  5.52it/s, loss=0.9329, rfu=0.4058, cpp=0.0464, grad=38.570]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  57%|█████▋    | 36/63 [00:06<00:04,  5.75it/s, loss=1.0910, rfu=0.3758, cpp=0.1555, grad=47.898]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  73%|███████▎  | 46/63 [00:08<00:02,  5.73it/s, loss=0.4431, rfu=0.2009, cpp=0.0063, grad=26.291]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  76%|███████▌  | 48/63 [00:08<00:02,  5.50it/s, loss=0.5588, rfu=0.1456, cpp=0.1195, grad=49.670]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 30/40:  84%|████████▍ | 53/63 [00:09<00:01,  5.79it/s, loss=0.8175, rfu=0.2646, cpp=0.1299, grad=43.649]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.748 ± 0.121
# 📊 Época  30 | Loss: 0.9017 | RFU_L: 0.2368 | CPP_L: 0.1998 | Val RMSE: 0.7862 | Val R²: 0.4778 | Val Acc: 0.5532 | Val F1: 0.5341 | Grad: 52.669
# Época 31/40:   0%|          | 0/63 [00:00<?, ?it/s]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:   5%|▍         | 3/63 [00:00<00:14,  4.09it/s, loss=0.8008, rfu=0.2090, cpp=0.1771, grad=46.222]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:  13%|█▎        | 8/63 [00:01<00:09,  5.58it/s, loss=0.8457, rfu=0.3100, cpp=0.0986, grad=43.809]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:  24%|██▍       | 15/63 [00:02<00:08,  5.79it/s, loss=0.8781, rfu=0.4240, cpp=0.0007, grad=27.381]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:  32%|███▏      | 20/63 [00:03<00:07,  5.71it/s, loss=0.7685, rfu=0.2425, cpp=0.1274, grad=32.730]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:  41%|████▏     | 26/63 [00:04<00:06,  5.79it/s, loss=0.6181, rfu=0.1757, cpp=0.1190, grad=49.975]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 31/40:
:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  29%|██▊       | 18/63 [00:03<00:07,  5.82it/s, loss=1.3423, rfu=0.4429, cpp=0.2140, grad=56.941]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  44%|████▍     | 28/63 [00:05<00:06,  5.54it/s, loss=0.6706, rfu=0.2775, cpp=0.0435, grad=33.001]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  48%|████▊     | 30/63 [00:05<00:06,  5.40it/s, loss=0.5136, rfu=0.2250, cpp=0.0175, grad=29.008]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  56%|█████▌    | 35/63 [00:06<00:05,  5.44it/s, loss=0.3105, rfu=0.1318, cpp=0.0092, grad=22.816]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  70%|██████▉   | 44/63 [00:07<00:03,  5.55it/s, loss=0.3808, rfu=0.1044, cpp=0.0717, grad=38.709]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  73%|███████▎  | 46/63 [00:08<00:03,  5.66it/s, loss=1.5388, rfu=0.4887, cpp=0.2664, grad=48.257]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  81%|████████  | 51/63 [00:09<00:02,  5.81it/s, loss=0.2794, rfu=0.0160, cpp=0.1094, grad=43.396]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Época 33/40:  92%|█████████▏| 58/63 [00:10<00:00,  5.72it/s, loss=0.9297, rfu=0.1910, cpp=0.2595, grad=53.999]:76: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Confianza promedio CPP: 0.671 ± 0.122
# 📊 Época  33 | Loss: 0.9179 | RFU_L: 0.2607 | CPP_L: 0.1839 | Val RMSE: 0.7435 | Val R²: 0.5329 | Val Acc: 0.6170 | Val F1: 0.6160 | Grad: 49.670
# Early stopping en época 33
# Error cargando checkpoint: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy._core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# No se pudo cargar el mejor modelo
# Gráficos de entrenamiento guardados en ./saved_model/training_history.png
# Final evaluation on test set...
# Confianza promedio CPP: 0.688 ± 0.115
# Gráficos de evaluación guardados en ./saved_model/evaluation_plots.png
#
# ============================================================
# FINAL RESULTS:
# ============================================================
#  RMSE (RFU): 0.6714
#  MAE (RFU): 0.5352
#  R² (RFU): 0.5643
#  Accuracy (CPP): 0.5091
#  F1-Score (CPP): 0.5042
# ============================================================
# Final metrics saved at ./saved_model/final_metrics.json
#
# Performing detailed analysis...
# Análisis detallado: 100%|██████████| 13/13 [00:06<00:00,  2.01it/s]
# ANÁLISIS ESTADÍSTICO DETALLADO:
# ==================================================
#    RFU - Estadísticas de Predicción:
#    Media predicha: 1.4573 ± 0.4902
#    Media real: 1.4747 ± 0.6524
#    Rango predicho: [0.1358, 2.2973]
#    Rango real: [-0.4089, 2.9323]
#    Percentiles predichos: [0.6765795  1.19405877 1.55590455 1.81049095 1.98799953]
#    Percentiles reales: [0.5670264  1.11046427 1.44932409 1.89944653 2.27590999]
#
#  CPP - Estadísticas de Clasificación:
#    Distribución predicha: [33 22]
#    Distribución real: [28 27]
#    Confianza promedio: 0.6878 ± 0.1146
#    Predicciones de alta confianza (>0.9): 3/55
# Reporte de Clasificación:
# ==================================================
#               precision    recall  f1-score   support
#
#      non-CPP       0.52      0.61      0.56        28
#          CPP       0.50      0.41      0.45        27
#
#     accuracy                           0.51        55
#    macro avg       0.51      0.51      0.50        55
# weighted avg       0.51      0.51      0.50        55
#
#  Análisis detallado completado
# Model configuration saved at ./saved_model/model_config.json
